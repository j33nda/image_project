# %%
import cv2
from ultralytics import YOLO

# %%
model = YOLO('yolo11x.pt')
# Out:
# ...
# 100%|████████████████████████████████████████| 109M/109M [00:24<00:00, 4.75MB/s]

# %%
model.predict('videos/rally.mov', save=True, imgsz=640, conf=0.3, device='mps', verbose = True, batch=1)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/7503) /Users/jenda/unive/IMAGE/project/videos/rally.mov: 384x640 12 persons, 142.5ms
# video 1/1 (frame 2/7503) /Users/jenda/unive/IMAGE/project/videos/rally.mov: 384x640 12 persons, 51.2ms
# video 1/1 (frame 3/7503) /Users/jenda/unive/IMAGE/project/videos/rally.mov: 384x640 12 persons, 47.4ms
# video 1/1 (frame 4/7503) /Users/jenda/unive/IMAGE/project/videos/rally.mov: 384x640 12 persons, 47.5ms
# ...
