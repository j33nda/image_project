# %%
import os
import cv2
import random

def load_yolo_labels(label_path):
    with open(label_path, "r") as f:
        for line in f.readlines():
            cls, x, y, w, h = map(float, line.strip().split())
            if cls == 0:
                return cls, x, y, w, h
            else: 
                print("Nemam balon")

def save_yolo_labels(label_path, label):
    with open(label_path, "w") as f:
        cls, x, y, w, h = label
        f.write(f"{int(cls)} {x:.6f} {y:.6f} {w:.6f} {h:.6f}\n")

def slice_dataset(
    images_dir,
    labels_dir,
    output_images_dir,
    output_labels_dir,
    slice_size=640,
    crops_per_image=3
):
    os.makedirs(output_images_dir, exist_ok=True)
    os.makedirs(output_labels_dir, exist_ok=True)

    for img_file in os.listdir(images_dir):
        if not img_file.lower().endswith((".jpg", ".png", ".jpeg")):
            print("nemam obr")
            continue

        img_path = os.path.join(images_dir, img_file)
        label_path = os.path.join(labels_dir, os.path.splitext(img_file)[0] + ".txt")

        if not os.path.exists(label_path):
            print("nemam label")
            continue

        img = cv2.imread(img_path)
        height, width = img.shape[:2]
        label = load_yolo_labels(label_path)
        print(height, width)


        if not label:
            print('nemam baloooon')
            continue

        for k in range(crops_per_image):
            print(img_path)
            cls, x, y, w, h = label

            x = int(x*width)
            y = int(y*height)
            w = int(w*width)
            h = int(h*height)
            
            print('w, h', w, h)
            print('width, height', width, height)


            if x + slice_size < width:
                x1 = random.randint(max(w, x-slice_size+w), x+w)
            else:
                x1 = random.randint(max(w, x-slice_size+w), width-slice_size+w)

                
            # x1 = random.randint(max(0, x-slice_size+w), max(width-slice_size-w, x - slice_size -w))
            # y1 = random.randint(max(0, y-slice_size+h), max(height-slice_size-h, y -slice_size- h))

            # x1 = random.randint(max(0, x-slice_size+w), max(width-slice_size+w, x - slice_size +w))
            y1 = random.randint(max(h, y-slice_size+h), max(height-slice_size+h, y -slice_size+ h))

            
            y2 = y1 + slice_size
            x2 = x1 + slice_size
            print(x1, y1, x2, y2)

            crop = img[y1:y2, x1:x2]

            x_new = (x-x1)/slice_size
            y_new = (y-y1)/slice_size
            w_new = w/slice_size
            h_new = h/slice_size

            new_labels = cls, x_new, y_new, w_new, h_new

            out_name = f"{os.path.splitext(img_file)[0]}_crop{k}.jpg"
            out_img_path = os.path.join(output_images_dir, out_name)
            out_label_path = os.path.join(output_labels_dir, os.path.splitext(out_name)[0] + ".txt")

            cv2.imwrite(out_img_path, crop)
            save_yolo_labels(out_label_path, new_labels)

            print(f"Saved crop: {out_img_path}")

# %%
slice_dataset(
    images_dir='datasets/new/images/train/',
    labels_dir='datasets/new/labels/train/',
    output_images_dir='datasets/new_sliced/images/train/',
    output_labels_dir='datasets/new_sliced/labels/train/',
    slice_size=640,
    crops_per_image=1
)
# Out:
# 1920 1080
# datasets/new/images/train/a2faa1c1-frame_190.jpg
# w, h 28 27
# width, height 1080 1920
# 115 1070 755 1710
# Saved crop: datasets/new_sliced/images/train/a2faa1c1-frame_190_crop0.jpg
# 720 1280
# datasets/new/images/train/cf780f70-frame_145.jpg
# w, h 13 13
# width, height 1280 720
# 376 15 1016 655
# Saved crop: datasets/new_sliced/images/train/cf780f70-frame_145_crop0.jpg
# 720 1280
# datasets/new/images/train/a7e51e29-frame_143.jpg
# w, h 13 13
# width, height 1280 720
# 446 81 1086 721
# Saved crop: datasets/new_sliced/images/train/a7e51e29-frame_143_crop0.jpg
# 1920 1080
# datasets/new/images/train/eafeaf44-frame_390.jpg
# w, h 23 24
# width, height 1080 1920
# 249 439 889 1079
# Saved crop: datasets/new_sliced/images/train/eafeaf44-frame_390_crop0.jpg
# 720 1280
# datasets/new/images/train/9d15be0e-frame_134.jpg
# w, h 14 15
# width, height 1280 720
# 591 4 1231 644
# Saved crop: datasets/new_sliced/images/train/9d15be0e-frame_134_crop0.jpg
# 720 1280
# datasets/new/images/train/d72b0215-frame_438.jpg
# w, h 13 13
# width, height 1280 720
# 333 85 973 725
# Saved crop: datasets/new_sliced/images/train/d72b0215-frame_438_crop0.jpg
# 720 1280
# datasets/new/images/train/9accaac9-frame_86.jpg
# w, h 12 12
# width, height 1280 720
# 430 64 1070 704
# Saved crop: datasets/new_sliced/images/train/9accaac9-frame_86_crop0.jpg
# 720 1280
# datasets/new/images/train/8111c129-frame_1261.jpg
# w, h 10 9
# width, height 1280 720
# 271 86 911 726
# Saved crop: datasets/new_sliced/images/train/8111c129-frame_1261_crop0.jpg
# 720 1280
# datasets/new/images/train/47946973-frame_2237.jpg
# w, h 13 13
# width, height 1280 720
# 183 4 823 644
# Saved crop: datasets/new_sliced/images/train/47946973-frame_2237_crop0.jpg
# 720 1280
# datasets/new/images/train/18eb6102-frame_312.jpg
# w, h 26 28
# width, height 1280 720
# 468 96 1108 736
# Saved crop: datasets/new_sliced/images/train/18eb6102-frame_312_crop0.jpg
# 720 1280
# datasets/new/images/train/ecffd3a4-frame_174.jpg
# w, h 13 12
# width, height 1280 720
# 272 11 912 651
# Saved crop: datasets/new_sliced/images/train/ecffd3a4-frame_174_crop0.jpg
# 720 1280
# datasets/new/images/train/15da00db-frame_214.jpg
# w, h 18 16
# width, height 1280 720
# 47 7 687 647
# Saved crop: datasets/new_sliced/images/train/15da00db-frame_214_crop0.jpg
# 720 1280
# datasets/new/images/train/c7d87d82-frame_270.jpg
# w, h 27 29
# width, height 1280 720
# 319 23 959 663
# Saved crop: datasets/new_sliced/images/train/c7d87d82-frame_270_crop0.jpg
# 720 1280
# datasets/new/images/train/9e262e97-frame_65.jpg
# w, h 10 9
# width, height 1280 720
# 588 71 1228 711
# Saved crop: datasets/new_sliced/images/train/9e262e97-frame_65_crop0.jpg
# 720 1280
# datasets/new/images/train/117cc8cc-frame_2224.jpg
# w, h 13 12
# width, height 1280 720
# 238 84 878 724
# Saved crop: datasets/new_sliced/images/train/117cc8cc-frame_2224_crop0.jpg
# 720 1280
# datasets/new/images/train/9d256d31-frame_78.jpg
# w, h 11 9
# width, height 1280 720
# 378 41 1018 681
# Saved crop: datasets/new_sliced/images/train/9d256d31-frame_78_crop0.jpg
# 720 1280
# datasets/new/images/train/e5a7d9c7-frame_950.jpg
# w, h 9 9
# width, height 1280 720
# 98 20 738 660
# Saved crop: datasets/new_sliced/images/train/e5a7d9c7-frame_950_crop0.jpg
# 1920 1080
# datasets/new/images/train/0c346d32-frame_730.jpg
# w, h 21 20
# width, height 1080 1920
# 331 1275 971 1915
# Saved crop: datasets/new_sliced/images/train/0c346d32-frame_730_crop0.jpg
# 720 1280
# datasets/new/images/train/50df7025-frame_2099.jpg
# w, h 40 38
# width, height 1280 720
# 297 34 937 674
# Saved crop: datasets/new_sliced/images/train/50df7025-frame_2099_crop0.jpg
# 720 1280
# datasets/new/images/train/8b9fa46a-frame_464.jpg
# w, h 17 16
# width, height 1280 720
# 229 35 869 675
# Saved crop: datasets/new_sliced/images/train/8b9fa46a-frame_464_crop0.jpg
# 720 1280
# datasets/new/images/train/cfa19aee-frame_5609.jpg
# w, h 16 18
# width, height 1280 720
# 251 17 891 657
# Saved crop: datasets/new_sliced/images/train/cfa19aee-frame_5609_crop0.jpg
# 720 1280
# datasets/new/images/train/fc904c2e-frame_746.jpg
# w, h 22 19
# width, height 1280 720
# 204 90 844 730
# Saved crop: datasets/new_sliced/images/train/fc904c2e-frame_746_crop0.jpg
# 720 1280
# datasets/new/images/train/35905db1-frame_44.jpg
# w, h 9 8
# width, height 1280 720
# 254 41 894 681
# Saved crop: datasets/new_sliced/images/train/35905db1-frame_44_crop0.jpg
# 720 1280
# datasets/new/images/train/07a35bdf-frame_1923.jpg
# w, h 14 13
# width, height 1280 720
# 490 45 1130 685
# Saved crop: datasets/new_sliced/images/train/07a35bdf-frame_1923_crop0.jpg
# 720 1280
# datasets/new/images/train/d45ada2f-frame_432.jpg
# w, h 16 15
# width, height 1280 720
# 368 75 1008 715
# Saved crop: datasets/new_sliced/images/train/d45ada2f-frame_432_crop0.jpg
# 720 1280
# datasets/new/images/train/88156266-frame_7035.jpg
# w, h 24 14
# width, height 1280 720
# 650 73 1290 713
# Saved crop: datasets/new_sliced/images/train/88156266-frame_7035_crop0.jpg
# 720 1280
# datasets/new/images/train/a9bd043f-frame_9807.jpg
# w, h 17 17
# width, height 1280 720
# 493 40 1133 680
# Saved crop: datasets/new_sliced/images/train/a9bd043f-frame_9807_crop0.jpg
# 720 1280
# datasets/new/images/train/86849475-frame_1273.jpg
# w, h 12 10
# width, height 1280 720
# 253 71 893 711
# Saved crop: datasets/new_sliced/images/train/86849475-frame_1273_crop0.jpg
# 720 1280
# datasets/new/images/train/830d9b14-frame_2138.jpg
# w, h 13 12
# width, height 1280 720
# 243 5 883 645
# Saved crop: datasets/new_sliced/images/train/830d9b14-frame_2138_crop0.jpg
# 720 1280
# datasets/new/images/train/42b7483f-frame_115.jpg
# w, h 15 14
# width, height 1280 720
# 390 64 1030 704
# Saved crop: datasets/new_sliced/images/train/42b7483f-frame_115_crop0.jpg
# 1920 1080
# datasets/new/images/train/5a896a0e-frame_770.jpg
# w, h 21 19
# width, height 1080 1920
# 164 795 804 1435
# Saved crop: datasets/new_sliced/images/train/5a896a0e-frame_770_crop0.jpg
# 720 1280
# datasets/new/images/train/6e124846-frame_2119.jpg
# w, h 26 27
# width, height 1280 720
# 178 1 818 641
# Saved crop: datasets/new_sliced/images/train/6e124846-frame_2119_crop0.jpg
# 1920 1080
# datasets/new/images/train/e9e13ad5-frame_540.jpg
# w, h 16 16
# width, height 1080 1920
# 434 427 1074 1067
# Saved crop: datasets/new_sliced/images/train/e9e13ad5-frame_540_crop0.jpg
# 720 1280
# datasets/new/images/train/fd018130-frame_185.jpg
# w, h 14 14
# width, height 1280 720
# 405 76 1045 716
# Saved crop: datasets/new_sliced/images/train/fd018130-frame_185_crop0.jpg
# 720 1280
# datasets/new/images/train/21538120-frame_1786.jpg
# w, h 14 14
# width, height 1280 720
# 252 77 892 717
# Saved crop: datasets/new_sliced/images/train/21538120-frame_1786_crop0.jpg
# 720 1280
# datasets/new/images/train/f7a5611c-frame_6629.jpg
# w, h 13 6
# width, height 1280 720
# 174 34 814 674
# Saved crop: datasets/new_sliced/images/train/f7a5611c-frame_6629_crop0.jpg
# 1920 1080
# datasets/new/images/train/4e75d2f9-frame_690.jpg
# w, h 23 21
# width, height 1080 1920
# 250 985 890 1625
# Saved crop: datasets/new_sliced/images/train/4e75d2f9-frame_690_crop0.jpg
# 720 1280
# datasets/new/images/train/e13781db-frame_139.jpg
# w, h 13 13
# width, height 1280 720
# 66 17 706 657
# Saved crop: datasets/new_sliced/images/train/e13781db-frame_139_crop0.jpg
# 720 1280
# datasets/new/images/train/eda9cac6-frame_1378.jpg
# w, h 35 35
# width, height 1280 720
# 580 103 1220 743
# Saved crop: datasets/new_sliced/images/train/eda9cac6-frame_1378_crop0.jpg
# 720 1280
# datasets/new/images/train/7023e9d1-frame_66.jpg
# w, h 11 11
# width, height 1280 720
# 569 78 1209 718
# Saved crop: datasets/new_sliced/images/train/7023e9d1-frame_66_crop0.jpg
# 720 1280
# datasets/new/images/train/af9d10dd-frame_3480.jpg
# w, h 18 19
# width, height 1280 720
# 574 39 1214 679
# Saved crop: datasets/new_sliced/images/train/af9d10dd-frame_3480_crop0.jpg
# 720 1280
# datasets/new/images/train/41e95af3-frame_12728.jpg
# w, h 51 50
# width, height 1280 720
# 626 6 1266 646
# Saved crop: datasets/new_sliced/images/train/41e95af3-frame_12728_crop0.jpg
# 720 1280
# datasets/new/images/train/36ae7e34-frame_5722.jpg
# w, h 13 14
# width, height 1280 720
# 379 21 1019 661
# Saved crop: datasets/new_sliced/images/train/36ae7e34-frame_5722_crop0.jpg
# 720 1280
# datasets/new/images/train/79a494dc-frame_6549.jpg
# w, h 14 13
# width, height 1280 720
# 100 36 740 676
# Saved crop: datasets/new_sliced/images/train/79a494dc-frame_6549_crop0.jpg
# 720 1280
# datasets/new/images/train/d82b8751-frame_1936.jpg
# w, h 13 12
# width, height 1280 720
# 511 34 1151 674
# Saved crop: datasets/new_sliced/images/train/d82b8751-frame_1936_crop0.jpg
# 1920 1080
# datasets/new/images/train/73cacced-frame_720.jpg
# w, h 21 23
# width, height 1080 1920
# 316 1167 956 1807
# Saved crop: datasets/new_sliced/images/train/73cacced-frame_720_crop0.jpg
# 720 1280
# datasets/new/images/train/483fb042-frame_1080.jpg
# w, h 14 13
# width, height 1280 720
# 492 33 1132 673
# Saved crop: datasets/new_sliced/images/train/483fb042-frame_1080_crop0.jpg
# 720 1280
# datasets/new/images/train/f648753b-frame_37.jpg
# w, h 11 11
# width, height 1280 720
# 324 13 964 653
# Saved crop: datasets/new_sliced/images/train/f648753b-frame_37_crop0.jpg
# 720 1280
# datasets/new/images/train/32fa5f71-frame_357.jpg
# w, h 16 14
# width, height 1280 720
# 1 12 641 652
# Saved crop: datasets/new_sliced/images/train/32fa5f71-frame_357_crop0.jpg
# 720 1280
# datasets/new/images/train/6cacfb0a-frame_2132.jpg
# w, h 16 15
# width, height 1280 720
# 630 52 1270 692
# Saved crop: datasets/new_sliced/images/train/6cacfb0a-frame_2132_crop0.jpg
# 720 1280
# datasets/new/images/train/efab5501-frame_128.jpg
# w, h 14 13
# width, height 1280 720
# 298 0 938 640
# Saved crop: datasets/new_sliced/images/train/efab5501-frame_128_crop0.jpg
# 720 1280
# datasets/new/images/train/53e6244d-frame_15.jpg
# w, h 18 16
# width, height 1280 720
# 153 38 793 678
# Saved crop: datasets/new_sliced/images/train/53e6244d-frame_15_crop0.jpg
# 720 1280
# datasets/new/images/train/8591d089-frame_52.jpg
# w, h 9 8
# width, height 1280 720
# 465 88 1105 728
# Saved crop: datasets/new_sliced/images/train/8591d089-frame_52_crop0.jpg
# 720 1280
# datasets/new/images/train/f6477422-frame_2100.jpg
# w, h 39 40
# width, height 1280 720
# 662 25 1302 665
# Saved crop: datasets/new_sliced/images/train/f6477422-frame_2100_crop0.jpg
# 720 1280
# datasets/new/images/train/d0f55092-frame_162.jpg
# w, h 14 13
# width, height 1280 720
# 518 87 1158 727
# Saved crop: datasets/new_sliced/images/train/d0f55092-frame_162_crop0.jpg
# 720 1280
# datasets/new/images/train/27c303cf-frame_6110.jpg
# w, h 16 14
# width, height 1280 720
# 233 27 873 667
# Saved crop: datasets/new_sliced/images/train/27c303cf-frame_6110_crop0.jpg
# 720 1280
# datasets/new/images/train/41d06b16-frame_1375.jpg
# w, h 40 35
# width, height 1280 720
# 578 21 1218 661
# Saved crop: datasets/new_sliced/images/train/41d06b16-frame_1375_crop0.jpg
# 720 1280
# datasets/new/images/train/adeaea48-frame_12966.jpg
# w, h 40 38
# width, height 1280 720
# 676 118 1316 758
# Saved crop: datasets/new_sliced/images/train/adeaea48-frame_12966_crop0.jpg
# 720 1280
# datasets/new/images/train/23ee51a2-frame_16.jpg
# w, h 15 14
# width, height 1280 720
# 87 1 727 641
# Saved crop: datasets/new_sliced/images/train/23ee51a2-frame_16_crop0.jpg
# 720 1280
# datasets/new/images/train/a12f10eb-frame_1387.jpg
# w, h 27 25
# width, height 1280 720
# 605 63 1245 703
# Saved crop: datasets/new_sliced/images/train/a12f10eb-frame_1387_crop0.jpg
# 720 1280
# datasets/new/images/train/54f56c6d-frame_333.jpg
# w, h 24 25
# width, height 1280 720
# 494 77 1134 717
# Saved crop: datasets/new_sliced/images/train/54f56c6d-frame_333_crop0.jpg
# 720 1280
# datasets/new/images/train/ccc66854-frame_1393.jpg
# w, h 19 20
# width, height 1280 720
# 451 33 1091 673
# Saved crop: datasets/new_sliced/images/train/ccc66854-frame_1393_crop0.jpg
# 720 1280
# datasets/new/images/train/3a533deb-frame_59.jpg
# w, h 11 11
# width, height 1280 720
# 28 12 668 652
# Saved crop: datasets/new_sliced/images/train/3a533deb-frame_59_crop0.jpg
# 720 1280
# datasets/new/images/train/c30b2d06-frame_54.jpg
# w, h 11 10
# width, height 1280 720
# 644 17 1284 657
# Saved crop: datasets/new_sliced/images/train/c30b2d06-frame_54_crop0.jpg
# 720 1280
# datasets/new/images/train/aa7720dd-frame_125.jpg
# w, h 14 15
# width, height 1280 720
# 210 53 850 693
# Saved crop: datasets/new_sliced/images/train/aa7720dd-frame_125_crop0.jpg
# 720 1280
# datasets/new/images/train/8c1498fb-frame_180.jpg
# w, h 14 14
# width, height 1280 720
# 273 1 913 641
# Saved crop: datasets/new_sliced/images/train/8c1498fb-frame_180_crop0.jpg
# 720 1280
# datasets/new/images/train/7b244a13-frame_72.jpg
# w, h 10 9
# width, height 1280 720
# 234 65 874 705
# Saved crop: datasets/new_sliced/images/train/7b244a13-frame_72_crop0.jpg
# 720 1280
# datasets/new/images/train/a4aae0e2-frame_1379.jpg
# w, h 38 36
# width, height 1280 720
# 611 94 1251 734
# Saved crop: datasets/new_sliced/images/train/a4aae0e2-frame_1379_crop0.jpg
# 720 1280
# datasets/new/images/train/325b0aa6-frame_74.jpg
# w, h 10 10
# width, height 1280 720
# 284 51 924 691
# Saved crop: datasets/new_sliced/images/train/325b0aa6-frame_74_crop0.jpg
# 720 1280
# datasets/new/images/train/2611d11d-frame_1805.jpg
# w, h 11 11
# width, height 1280 720
# 307 24 947 664
# Saved crop: datasets/new_sliced/images/train/2611d11d-frame_1805_crop0.jpg
# 720 1280
# datasets/new/images/train/8a02c4c6-frame_1440.jpg
# w, h 13 13
# width, height 1280 720
# 211 71 851 711
# Saved crop: datasets/new_sliced/images/train/8a02c4c6-frame_1440_crop0.jpg
# 720 1280
# datasets/new/images/train/c047a3ef-frame_84.jpg
# w, h 15 15
# width, height 1280 720
# 70 64 710 704
# Saved crop: datasets/new_sliced/images/train/c047a3ef-frame_84_crop0.jpg
# 720 1280
# datasets/new/images/train/7ec6e6c2-frame_36.jpg
# w, h 13 10
# width, height 1280 720
# 278 7 918 647
# Saved crop: datasets/new_sliced/images/train/7ec6e6c2-frame_36_crop0.jpg
# 720 1280
# datasets/new/images/train/2e5450f2-frame_1087.jpg
# w, h 10 9
# width, height 1280 720
# 647 20 1287 660
# Saved crop: datasets/new_sliced/images/train/2e5450f2-frame_1087_crop0.jpg
# 1920 1080
# datasets/new/images/train/aeed7d06-frame_380.jpg
# w, h 24 25
# width, height 1080 1920
# 254 1112 894 1752
# Saved crop: datasets/new_sliced/images/train/aeed7d06-frame_380_crop0.jpg
# 720 1280
# datasets/new/images/train/5df31778-frame_724.jpg
# w, h 19 15
# width, height 1280 720
# 317 89 957 729
# Saved crop: datasets/new_sliced/images/train/5df31778-frame_724_crop0.jpg
# 720 1280
# datasets/new/images/train/7921102c-frame_118.jpg
# w, h 13 13
# width, height 1280 720
# 158 36 798 676
# Saved crop: datasets/new_sliced/images/train/7921102c-frame_118_crop0.jpg
# 720 1280
# datasets/new/images/train/223ca940-frame_195.jpg
# w, h 11 12
# width, height 1280 720
# 614 16 1254 656
# Saved crop: datasets/new_sliced/images/train/223ca940-frame_195_crop0.jpg
# 720 1280
# datasets/new/images/train/dff7741a-frame_177.jpg
# w, h 13 13
# width, height 1280 720
# 595 13 1235 653
# Saved crop: datasets/new_sliced/images/train/dff7741a-frame_177_crop0.jpg
# 720 1280
# datasets/new/images/train/ca6c6850-frame_148.jpg
# w, h 13 12
# width, height 1280 720
# 245 49 885 689
# Saved crop: datasets/new_sliced/images/train/ca6c6850-frame_148_crop0.jpg
# 720 1280
# datasets/new/images/train/18177e15-frame_1970.jpg
# w, h 12 14
# width, height 1280 720
# 165 48 805 688
# Saved crop: datasets/new_sliced/images/train/18177e15-frame_1970_crop0.jpg
# 720 1280
# datasets/new/images/train/3ba4b932-frame_294.jpg
# w, h 15 14
# width, height 1280 720
# 481 87 1121 727
# Saved crop: datasets/new_sliced/images/train/3ba4b932-frame_294_crop0.jpg
# 720 1280
# datasets/new/images/train/c7538ff9-frame_110.jpg
# w, h 12 10
# width, height 1280 720
# 220 75 860 715
# Saved crop: datasets/new_sliced/images/train/c7538ff9-frame_110_crop0.jpg
# 1920 1080
# datasets/new/images/train/2f31c074-frame_170.jpg
# w, h 24 22
# width, height 1080 1920
# 177 415 817 1055
# Saved crop: datasets/new_sliced/images/train/2f31c074-frame_170_crop0.jpg
# 720 1280
# datasets/new/images/train/44e779a8-frame_1380.jpg
# w, h 38 35
# width, height 1280 720
# 600 41 1240 681
# Saved crop: datasets/new_sliced/images/train/44e779a8-frame_1380_crop0.jpg
# 720 1280
# datasets/new/images/train/b1c06b43-frame_87.jpg
# w, h 11 11
# width, height 1280 720
# 580 17 1220 657
# Saved crop: datasets/new_sliced/images/train/b1c06b43-frame_87_crop0.jpg
# 720 1280
# datasets/new/images/train/f5e5ce19-frame_2104.jpg
# w, h 40 38
# width, height 1280 720
# 596 60 1236 700
# Saved crop: datasets/new_sliced/images/train/f5e5ce19-frame_2104_crop0.jpg
# 720 1280
# datasets/new/images/train/7c7efa07-frame_67.jpg
# w, h 11 11
# width, height 1280 720
# 242 91 882 731
# Saved crop: datasets/new_sliced/images/train/7c7efa07-frame_67_crop0.jpg
# nemam obr
# 720 1280
# datasets/new/images/train/f0e4ba04-frame_120.jpg
# w, h 13 14
# width, height 1280 720
# 447 13 1087 653
# Saved crop: datasets/new_sliced/images/train/f0e4ba04-frame_120_crop0.jpg
# 720 1280
# datasets/new/images/train/a0d87d4d-frame_2188.jpg
# w, h 14 14
# width, height 1280 720
# 162 23 802 663
# Saved crop: datasets/new_sliced/images/train/a0d87d4d-frame_2188_crop0.jpg
# 720 1280
# datasets/new/images/train/5d49d98d-frame_1266.jpg
# w, h 11 11
# width, height 1280 720
# 156 44 796 684
# Saved crop: datasets/new_sliced/images/train/5d49d98d-frame_1266_crop0.jpg
# 720 1280
# datasets/new/images/train/f65949a6-frame_2126.jpg
# w, h 19 19
# width, height 1280 720
# 160 91 800 731
# Saved crop: datasets/new_sliced/images/train/f65949a6-frame_2126_crop0.jpg
# 720 1280
# datasets/new/images/train/8d615d20-frame_710.jpg
# w, h 23 24
# width, height 1280 720
# 412 79 1052 719
# Saved crop: datasets/new_sliced/images/train/8d615d20-frame_710_crop0.jpg
# 720 1280
# datasets/new/images/train/c19055d5-frame_194.jpg
# w, h 14 13
# width, height 1280 720
# 645 45 1285 685
# Saved crop: datasets/new_sliced/images/train/c19055d5-frame_194_crop0.jpg
# 720 1280
# datasets/new/images/train/79998a66-frame_985.jpg
# w, h 15 10
# width, height 1280 720
# 249 9 889 649
# Saved crop: datasets/new_sliced/images/train/79998a66-frame_985_crop0.jpg
# 1920 1080
# datasets/new/images/train/9ad0d8b9-frame_990.jpg
# w, h 18 18
# width, height 1080 1920
# 190 448 830 1088
# Saved crop: datasets/new_sliced/images/train/9ad0d8b9-frame_990_crop0.jpg
# 720 1280
# datasets/new/images/train/16e42a52-frame_1356.jpg
# w, h 10 12
# width, height 1280 720
# 265 57 905 697
# Saved crop: datasets/new_sliced/images/train/16e42a52-frame_1356_crop0.jpg
# 1920 1080
# datasets/new/images/train/b98d7db3-frame_1000.jpg
# w, h 17 18
# width, height 1080 1920
# 18 1000 658 1640
# Saved crop: datasets/new_sliced/images/train/b98d7db3-frame_1000_crop0.jpg
# 1920 1080
# datasets/new/images/train/bb108c88-frame_240.jpg
# w, h 30 32
# width, height 1080 1920
# 313 1016 953 1656
# Saved crop: datasets/new_sliced/images/train/bb108c88-frame_240_crop0.jpg
# 720 1280
# datasets/new/images/train/102585c7-frame_1383.jpg
# w, h 34 32
# width, height 1280 720
# 407 31 1047 671
# Saved crop: datasets/new_sliced/images/train/102585c7-frame_1383_crop0.jpg
# 720 1280
# datasets/new/images/train/cfde22d2-frame_1508.jpg
# w, h 17 15
# width, height 1280 720
# 240 95 880 735
# Saved crop: datasets/new_sliced/images/train/cfde22d2-frame_1508_crop0.jpg
# 720 1280
# datasets/new/images/train/2bf29e82-frame_14025.jpg
# w, h 23 19
# width, height 1280 720
# 346 45 986 685
# Saved crop: datasets/new_sliced/images/train/2bf29e82-frame_14025_crop0.jpg
# 720 1280
# datasets/new/images/train/e1451ba5-frame_1405.jpg
# w, h 14 14
# width, height 1280 720
# 172 73 812 713
# Saved crop: datasets/new_sliced/images/train/e1451ba5-frame_1405_crop0.jpg
# 720 1280
# datasets/new/images/train/94a8d589-frame_1412.jpg
# w, h 12 12
# width, height 1280 720
# 492 30 1132 670
# Saved crop: datasets/new_sliced/images/train/94a8d589-frame_1412_crop0.jpg
# 720 1280
# datasets/new/images/train/5f331f7a-frame_402.jpg
# w, h 18 18
# width, height 1280 720
# 416 71 1056 711
# Saved crop: datasets/new_sliced/images/train/5f331f7a-frame_402_crop0.jpg
# 1920 1080
# datasets/new/images/train/138e64c1-frame_620.jpg
# w, h 18 18
# width, height 1080 1920
# 241 426 881 1066
# Saved crop: datasets/new_sliced/images/train/138e64c1-frame_620_crop0.jpg
# 720 1280
# datasets/new/images/train/cee78a4d-frame_1133.jpg
# w, h 10 9
# width, height 1280 720
# 190 59 830 699
# Saved crop: datasets/new_sliced/images/train/cee78a4d-frame_1133_crop0.jpg
# 720 1280
# datasets/new/images/train/541a8402-frame_119.jpg
# w, h 14 13
# width, height 1280 720
# 156 85 796 725
# Saved crop: datasets/new_sliced/images/train/541a8402-frame_119_crop0.jpg
# 1920 1080
# datasets/new/images/train/3c8b31ae-frame_530.jpg
# w, h 15 15
# width, height 1080 1920
# 284 1044 924 1684
# Saved crop: datasets/new_sliced/images/train/3c8b31ae-frame_530_crop0.jpg
# 720 1280
# datasets/new/images/train/5a98877f-frame_990.jpg
# w, h 16 13
# width, height 1280 720
# 153 39 793 679
# Saved crop: datasets/new_sliced/images/train/5a98877f-frame_990_crop0.jpg
# 720 1280
# datasets/new/images/train/56b8565b-frame_1596.jpg
# w, h 15 14
# width, height 1280 720
# 548 46 1188 686
# Saved crop: datasets/new_sliced/images/train/56b8565b-frame_1596_crop0.jpg
# 1920 1080
# datasets/new/images/train/d23c1b64-frame_250.jpg
# w, h 30 33
# width, height 1080 1920
# 249 634 889 1274
# Saved crop: datasets/new_sliced/images/train/d23c1b64-frame_250_crop0.jpg
# 720 1280
# datasets/new/images/train/814e1fa5-frame_2399.jpg
# w, h 13 10
# width, height 1280 720
# 172 59 812 699
# Saved crop: datasets/new_sliced/images/train/814e1fa5-frame_2399_crop0.jpg
# 720 1280
# datasets/new/images/train/19350972-frame_130.jpg
# w, h 13 13
# width, height 1280 720
# 215 51 855 691
# Saved crop: datasets/new_sliced/images/train/19350972-frame_130_crop0.jpg
# 1920 1080
# datasets/new/images/train/6b4891b2-frame_640.jpg
# w, h 19 16
# width, height 1080 1920
# 225 284 865 924
# Saved crop: datasets/new_sliced/images/train/6b4891b2-frame_640_crop0.jpg
# 720 1280
# datasets/new/images/train/3a385334-frame_1538.jpg
# w, h 15 17
# width, height 1280 720
# 231 57 871 697
# Saved crop: datasets/new_sliced/images/train/3a385334-frame_1538_crop0.jpg
# 720 1280
# datasets/new/images/train/73150ca0-frame_68.jpg
# w, h 11 10
# width, height 1280 720
# 157 34 797 674
# Saved crop: datasets/new_sliced/images/train/73150ca0-frame_68_crop0.jpg
# 720 1280
# datasets/new/images/train/3393597f-frame_1022.jpg
# w, h 14 14
# width, height 1280 720
# 371 69 1011 709
# Saved crop: datasets/new_sliced/images/train/3393597f-frame_1022_crop0.jpg
# 1920 1080
# datasets/new/images/train/9673d359-frame_830.jpg
# w, h 20 19
# width, height 1080 1920
# 242 1056 882 1696
# Saved crop: datasets/new_sliced/images/train/9673d359-frame_830_crop0.jpg
# 720 1280
# datasets/new/images/train/0421d9e8-frame_73.jpg
# w, h 8 8
# width, height 1280 720
# 408 20 1048 660
# Saved crop: datasets/new_sliced/images/train/0421d9e8-frame_73_crop0.jpg
# 720 1280
# datasets/new/images/train/6d6ffde7-frame_2120.jpg
# w, h 26 27
# width, height 1280 720
# 585 88 1225 728
# Saved crop: datasets/new_sliced/images/train/6d6ffde7-frame_2120_crop0.jpg
# 720 1280
# datasets/new/images/train/276981ed-frame_168.jpg
# w, h 12 12
# width, height 1280 720
# 610 12 1250 652
# Saved crop: datasets/new_sliced/images/train/276981ed-frame_168_crop0.jpg
# 720 1280
# datasets/new/images/train/62cbd320-frame_1474.jpg
# w, h 17 16
# width, height 1280 720
# 232 20 872 660
# Saved crop: datasets/new_sliced/images/train/62cbd320-frame_1474_crop0.jpg
# 720 1280
# datasets/new/images/train/7068f2b4-frame_47.jpg
# w, h 11 9
# width, height 1280 720
# 219 45 859 685
# Saved crop: datasets/new_sliced/images/train/7068f2b4-frame_47_crop0.jpg
# 1920 1080
# datasets/new/images/train/4d2725c2-frame_850.jpg
# w, h 19 20
# width, height 1080 1920
# 100 463 740 1103
# Saved crop: datasets/new_sliced/images/train/4d2725c2-frame_850_crop0.jpg
# 720 1280
# datasets/new/images/train/ca61bd41-frame_9785.jpg
# w, h 18 17
# width, height 1280 720
# 480 90 1120 730
# Saved crop: datasets/new_sliced/images/train/ca61bd41-frame_9785_crop0.jpg
# 720 1280
# datasets/new/images/train/4c048554-frame_12854.jpg
# w, h 42 43
# width, height 1280 720
# 671 52 1311 692
# Saved crop: datasets/new_sliced/images/train/4c048554-frame_12854_crop0.jpg
# 720 1280
# datasets/new/images/train/01fa9f72-frame_155.jpg
# w, h 13 13
# width, height 1280 720
# 572 38 1212 678
# Saved crop: datasets/new_sliced/images/train/01fa9f72-frame_155_crop0.jpg
# 720 1280
# datasets/new/images/train/dabf6698-frame_2206.jpg
# w, h 14 13
# width, height 1280 720
# 41 62 681 702
# Saved crop: datasets/new_sliced/images/train/dabf6698-frame_2206_crop0.jpg
# 1920 1080
# datasets/new/images/train/4344b90e-frame_810.jpg
# w, h 20 20
# width, height 1080 1920
# 303 877 943 1517
# Saved crop: datasets/new_sliced/images/train/4344b90e-frame_810_crop0.jpg
# 720 1280
# datasets/new/images/train/3eb1a95b-frame_750.jpg
# w, h 17 18
# width, height 1280 720
# 74 24 714 664
# Saved crop: datasets/new_sliced/images/train/3eb1a95b-frame_750_crop0.jpg
# 1920 1080
# datasets/new/images/train/fb616b20-frame_870.jpg
# w, h 19 19
# width, height 1080 1920
# 343 1183 983 1823
# Saved crop: datasets/new_sliced/images/train/fb616b20-frame_870_crop0.jpg
# 720 1280
# datasets/new/images/train/e16776be-frame_28.jpg
# w, h 13 11
# width, height 1280 720
# 367 81 1007 721
# Saved crop: datasets/new_sliced/images/train/e16776be-frame_28_crop0.jpg
# 1920 1080
# datasets/new/images/train/a839d97a-frame_840.jpg
# w, h 20 20
# width, height 1080 1920
# 28 658 668 1298
# Saved crop: datasets/new_sliced/images/train/a839d97a-frame_840_crop0.jpg
# 720 1280
# datasets/new/images/train/cb42d6d7-frame_7420.jpeg
# w, h 13 10
# width, height 1280 720
# 43 58 683 698
# Saved crop: datasets/new_sliced/images/train/cb42d6d7-frame_7420_crop0.jpg
# 720 1280
# datasets/new/images/train/8f034ef0-frame_2156.jpg
# w, h 15 13
# width, height 1280 720
# 272 78 912 718
# Saved crop: datasets/new_sliced/images/train/8f034ef0-frame_2156_crop0.jpg
# 720 1280
# datasets/new/images/train/7a098ca0-frame_124.jpg
# w, h 13 14
# width, height 1280 720
# 80 8 720 648
# Saved crop: datasets/new_sliced/images/train/7a098ca0-frame_124_crop0.jpg
# 720 1280
# datasets/new/images/train/d2e827ce-frame_1312.jpg
# w, h 15 14
# width, height 1280 720
# 245 4 885 644
# Saved crop: datasets/new_sliced/images/train/d2e827ce-frame_1312_crop0.jpg
# 720 1280
# datasets/new/images/train/ed1bf7ce-frame_1388.jpg
# w, h 24 23
# width, height 1280 720
# 656 8 1296 648
# Saved crop: datasets/new_sliced/images/train/ed1bf7ce-frame_1388_crop0.jpg
# 720 1280
# datasets/new/images/train/e164e7f8-frame_12978.jpg
# w, h 44 43
# width, height 1280 720
# 677 59 1317 699
# Saved crop: datasets/new_sliced/images/train/e164e7f8-frame_12978_crop0.jpg
# 720 1280
# datasets/new/images/train/e2a565a5-frame_984.jpg
# w, h 15 16
# width, height 1280 720
# 117 49 757 689
# Saved crop: datasets/new_sliced/images/train/e2a565a5-frame_984_crop0.jpg
# 720 1280
# datasets/new/images/train/654dc589-frame_166.jpg
# w, h 13 13
# width, height 1280 720
# 608 91 1248 731
# Saved crop: datasets/new_sliced/images/train/654dc589-frame_166_crop0.jpg
# 720 1280
# datasets/new/images/train/dc10b5a2-frame_90.jpg
# w, h 12 11
# width, height 1280 720
# 260 58 900 698
# Saved crop: datasets/new_sliced/images/train/dc10b5a2-frame_90_crop0.jpg
# 720 1280
# datasets/new/images/train/86ddc91d-frame_1373.jpg
# w, h 40 37
# width, height 1280 720
# 625 91 1265 731
# Saved crop: datasets/new_sliced/images/train/86ddc91d-frame_1373_crop0.jpg
# 720 1280
# datasets/new/images/train/c7b0e48e-frame_43.jpg
# w, h 11 7
# width, height 1280 720
# 599 10 1239 650
# Saved crop: datasets/new_sliced/images/train/c7b0e48e-frame_43_crop0.jpg
# 720 1280
# datasets/new/images/train/76cbdc99-frame_1593.jpg
# w, h 12 11
# width, height 1280 720
# 585 88 1225 728
# Saved crop: datasets/new_sliced/images/train/76cbdc99-frame_1593_crop0.jpg
# 720 1280
# datasets/new/images/train/039b039e-frame_5476.jpg
# w, h 10 7
# width, height 1280 720
# 49 38 689 678
# Saved crop: datasets/new_sliced/images/train/039b039e-frame_5476_crop0.jpg
# 720 1280
# datasets/new/images/train/c27fbca1-frame_1226.jpg
# w, h 9 9
# width, height 1280 720
# 232 48 872 688
# Saved crop: datasets/new_sliced/images/train/c27fbca1-frame_1226_crop0.jpg
# 720 1280
# datasets/new/images/train/bfb5a3e2-frame_80.jpg
# w, h 11 12
# width, height 1280 720
# 425 38 1065 678
# Saved crop: datasets/new_sliced/images/train/bfb5a3e2-frame_80_crop0.jpg
# 720 1280
# datasets/new/images/train/71c4ce23-frame_32.jpg
# w, h 12 10
# width, height 1280 720
# 172 42 812 682
# Saved crop: datasets/new_sliced/images/train/71c4ce23-frame_32_crop0.jpg
# 720 1280
# datasets/new/images/train/9fc81b1e-frame_1390.jpg
# w, h 23 23
# width, height 1280 720
# 608 87 1248 727
# Saved crop: datasets/new_sliced/images/train/9fc81b1e-frame_1390_crop0.jpg
# 720 1280
# datasets/new/images/train/a0535b02-frame_1337.jpg
# w, h 14 13
# width, height 1280 720
# 68 14 708 654
# Saved crop: datasets/new_sliced/images/train/a0535b02-frame_1337_crop0.jpg
# 720 1280
# datasets/new/images/train/53279b37-frame_1850.jpg
# w, h 14 15
# width, height 1280 720
# 507 3 1147 643
# Saved crop: datasets/new_sliced/images/train/53279b37-frame_1850_crop0.jpg
# 720 1280
# datasets/new/images/train/87205996-frame_2115.jpg
# w, h 32 32
# width, height 1280 720
# 97 39 737 679
# Saved crop: datasets/new_sliced/images/train/87205996-frame_2115_crop0.jpg
# 1920 1080
# datasets/new/images/train/367aa00b-frame_510.jpg
# w, h 14 14
# width, height 1080 1920
# 180 921 820 1561
# Saved crop: datasets/new_sliced/images/train/367aa00b-frame_510_crop0.jpg
# 1920 1080
# datasets/new/images/train/7f94026a-frame_570.jpg
# w, h 17 17
# width, height 1080 1920
# 196 833 836 1473
# Saved crop: datasets/new_sliced/images/train/7f94026a-frame_570_crop0.jpg
# 720 1280
# datasets/new/images/train/5890244b-frame_82.jpg
# w, h 13 11
# width, height 1280 720
# 398 83 1038 723
# Saved crop: datasets/new_sliced/images/train/5890244b-frame_82_crop0.jpg
# 720 1280
# datasets/new/images/train/7d888bf5-frame_148.jpg
# w, h 19 23
# width, height 1280 720
# 398 67 1038 707
# Saved crop: datasets/new_sliced/images/train/7d888bf5-frame_148_crop0.jpg
# 720 1280
# datasets/new/images/train/8b307288-frame_1998.jpg
# w, h 15 13
# width, height 1280 720
# 240 62 880 702
# Saved crop: datasets/new_sliced/images/train/8b307288-frame_1998_crop0.jpg
# 720 1280
# datasets/new/images/train/0498018c-frame_46.jpg
# w, h 9 8
# width, height 1280 720
# 605 5 1245 645
# Saved crop: datasets/new_sliced/images/train/0498018c-frame_46_crop0.jpg
# 720 1280
# datasets/new/images/train/1a97bbad-frame_2353.jpg
# w, h 13 11
# width, height 1280 720
# 51 84 691 724
# Saved crop: datasets/new_sliced/images/train/1a97bbad-frame_2353_crop0.jpg
# 720 1280
# datasets/new/images/train/979bdf53-frame_183.jpg
# w, h 14 13
# width, height 1280 720
# 498 71 1138 711
# Saved crop: datasets/new_sliced/images/train/979bdf53-frame_183_crop0.jpg
# 720 1280
# datasets/new/images/train/29980e1b-frame_1573.jpg
# w, h 16 14
# width, height 1280 720
# 566 1 1206 641
# Saved crop: datasets/new_sliced/images/train/29980e1b-frame_1573_crop0.jpg
# 720 1280
# datasets/new/images/train/3a79b66a-frame_1371.jpg
# w, h 40 38
# width, height 1280 720
# 473 69 1113 709
# Saved crop: datasets/new_sliced/images/train/3a79b66a-frame_1371_crop0.jpg
# 720 1280
# datasets/new/images/train/e69dbe18-frame_2108.jpg
# w, h 38 39
# width, height 1280 720
# 270 31 910 671
# Saved crop: datasets/new_sliced/images/train/e69dbe18-frame_2108_crop0.jpg
# 720 1280
# datasets/new/images/train/860c1888-frame_7112.jpg
# w, h 16 14
# width, height 1280 720
# 372 79 1012 719
# Saved crop: datasets/new_sliced/images/train/860c1888-frame_7112_crop0.jpg
# 720 1280
# datasets/new/images/train/4fed7c94-frame_35.jpg
# w, h 12 11
# width, height 1280 720
# 203 23 843 663
# Saved crop: datasets/new_sliced/images/train/4fed7c94-frame_35_crop0.jpg
# 720 1280
# datasets/new/images/train/841550d9-frame_1382.jpg
# w, h 34 32
# width, height 1280 720
# 623 102 1263 742
# Saved crop: datasets/new_sliced/images/train/841550d9-frame_1382_crop0.jpg
# 720 1280
# datasets/new/images/train/b3184aea-frame_1642.jpg
# w, h 14 13
# width, height 1280 720
# 367 3 1007 643
# Saved crop: datasets/new_sliced/images/train/b3184aea-frame_1642_crop0.jpg
# 720 1280
# datasets/new/images/train/12b74e1f-frame_62.jpg
# w, h 10 10
# width, height 1280 720
# 162 46 802 686
# Saved crop: datasets/new_sliced/images/train/12b74e1f-frame_62_crop0.jpg
# 720 1280
# datasets/new/images/train/348ed0a7-frame_84.jpg
# w, h 11 12
# width, height 1280 720
# 352 74 992 714
# Saved crop: datasets/new_sliced/images/train/348ed0a7-frame_84_crop0.jpg
# 720 1280
# datasets/new/images/train/59279bfd-frame_71.jpg
# w, h 10 9
# width, height 1280 720
# 307 41 947 681
# Saved crop: datasets/new_sliced/images/train/59279bfd-frame_71_crop0.jpg
# 720 1280
# datasets/new/images/train/07528459-frame_1618.jpg
# w, h 12 12
# width, height 1280 720
# 460 70 1100 710
# Saved crop: datasets/new_sliced/images/train/07528459-frame_1618_crop0.jpg
# 720 1280
# datasets/new/images/train/98213dad-frame_1394.jpg
# w, h 19 19
# width, height 1280 720
# 387 15 1027 655
# Saved crop: datasets/new_sliced/images/train/98213dad-frame_1394_crop0.jpg
# 720 1280
# datasets/new/images/train/9d84c56d-frame_2100.jpg
# w, h 40 40
# width, height 1280 720
# 667 94 1307 734
# Saved crop: datasets/new_sliced/images/train/9d84c56d-frame_2100_crop0.jpg
# 720 1280
# datasets/new/images/train/b23fa576-frame_6675.jpg
# w, h 14 12
# width, height 1280 720
# 434 25 1074 665
# Saved crop: datasets/new_sliced/images/train/b23fa576-frame_6675_crop0.jpg
# 720 1280
# datasets/new/images/train/d21cacf5-frame_322.jpg
# w, h 24 26
# width, height 1280 720
# 518 105 1158 745
# Saved crop: datasets/new_sliced/images/train/d21cacf5-frame_322_crop0.jpg
# 720 1280
# datasets/new/images/train/8b23a75c-frame_12988.jpg
# w, h 45 42
# width, height 1280 720
# 652 19 1292 659
# Saved crop: datasets/new_sliced/images/train/8b23a75c-frame_12988_crop0.jpg
# 720 1280
# datasets/new/images/train/fc43be0b-frame_25.jpg
# w, h 10 9
# width, height 1280 720
# 429 4 1069 644
# Saved crop: datasets/new_sliced/images/train/fc43be0b-frame_25_crop0.jpg
# 1920 1080
# datasets/new/images/train/755f13fd-frame_750.jpg
# w, h 19 20
# width, height 1080 1920
# 221 1297 861 1937
# Saved crop: datasets/new_sliced/images/train/755f13fd-frame_750_crop0.jpg
# 720 1280
# datasets/new/images/train/c5c4d150-frame_94.jpg
# w, h 12 11
# width, height 1280 720
# 499 23 1139 663
# Saved crop: datasets/new_sliced/images/train/c5c4d150-frame_94_crop0.jpg
# 720 1280
# datasets/new/images/train/d4df8dd4-frame_184.jpg
# w, h 14 12
# width, height 1280 720
# 302 27 942 667
# Saved crop: datasets/new_sliced/images/train/d4df8dd4-frame_184_crop0.jpg
# 720 1280
# datasets/new/images/train/379be018-frame_1567.jpg
# w, h 14 12
# width, height 1280 720
# 453 60 1093 700
# Saved crop: datasets/new_sliced/images/train/379be018-frame_1567_crop0.jpg
# 1920 1080
# datasets/new/images/train/24b77c82-frame_440.jpg
# w, h 17 17
# width, height 1080 1920
# 82 655 722 1295
# Saved crop: datasets/new_sliced/images/train/24b77c82-frame_440_crop0.jpg
# 720 1280
# datasets/new/images/train/7fe7e6b4-frame_1796.jpg
# w, h 13 13
# width, height 1280 720
# 0 55 640 695
# Saved crop: datasets/new_sliced/images/train/7fe7e6b4-frame_1796_crop0.jpg
# 1920 1080
# datasets/new/images/train/0da95d3c-frame_230.jpg
# w, h 31 31
# width, height 1080 1920
# 39 431 679 1071
# Saved crop: datasets/new_sliced/images/train/0da95d3c-frame_230_crop0.jpg
# 720 1280
# datasets/new/images/train/e82a27e1-frame_1812.jpg
# w, h 15 14
# width, height 1280 720
# 39 87 679 727
# Saved crop: datasets/new_sliced/images/train/e82a27e1-frame_1812_crop0.jpg
# 720 1280
# datasets/new/images/train/c5d3f0b4-frame_56.jpg
# w, h 11 10
# width, height 1280 720
# 559 41 1199 681
# Saved crop: datasets/new_sliced/images/train/c5d3f0b4-frame_56_crop0.jpg
# 720 1280
# datasets/new/images/train/b90a1a72-frame_2168.jpg
# w, h 13 11
# width, height 1280 720
# 70 41 710 681
# Saved crop: datasets/new_sliced/images/train/b90a1a72-frame_2168_crop0.jpg
# 720 1280
# datasets/new/images/train/6df2388e-frame_113.jpg
# w, h 15 13
# width, height 1280 720
# 506 23 1146 663
# Saved crop: datasets/new_sliced/images/train/6df2388e-frame_113_crop0.jpg
# 1920 1080
# datasets/new/images/train/3c638b20-frame_580.jpg
# w, h 16 15
# width, height 1080 1920
# 298 521 938 1161
# Saved crop: datasets/new_sliced/images/train/3c638b20-frame_580_crop0.jpg
# 720 1280
# datasets/new/images/train/36ece60f-frame_1840.jpg
# w, h 15 14
# width, height 1280 720
# 63 2 703 642
# Saved crop: datasets/new_sliced/images/train/36ece60f-frame_1840_crop0.jpg
# 720 1280
# datasets/new/images/train/78debfe3-frame_170.jpg
# w, h 13 12
# width, height 1280 720
# 648 47 1288 687
# Saved crop: datasets/new_sliced/images/train/78debfe3-frame_170_crop0.jpg
# 720 1280
# datasets/new/images/train/d9567bb0-frame_266.jpg
# w, h 28 30
# width, height 1280 720
# 309 6 949 646
# Saved crop: datasets/new_sliced/images/train/d9567bb0-frame_266_crop0.jpg
# 720 1280
# datasets/new/images/train/18414f80-frame_103.jpg
# w, h 12 11
# width, height 1280 720
# 355 47 995 687
# Saved crop: datasets/new_sliced/images/train/18414f80-frame_103_crop0.jpg
# 720 1280
# datasets/new/images/train/30458163-frame_1350.jpg
# w, h 11 12
# width, height 1280 720
# 310 9 950 649
# Saved crop: datasets/new_sliced/images/train/30458163-frame_1350_crop0.jpg
# 720 1280
# datasets/new/images/train/3d896d4a-frame_97.jpg
# w, h 11 11
# width, height 1280 720
# 635 15 1275 655
# Saved crop: datasets/new_sliced/images/train/3d896d4a-frame_97_crop0.jpg
# 720 1280
# datasets/new/images/train/55ee6739-frame_141.jpg
# w, h 11 10
# width, height 1280 720
# 478 54 1118 694
# Saved crop: datasets/new_sliced/images/train/55ee6739-frame_141_crop0.jpg
# 720 1280
# datasets/new/images/train/60cb6fbb-frame_1781.jpg
# w, h 14 13
# width, height 1280 720
# 62 64 702 704
# Saved crop: datasets/new_sliced/images/train/60cb6fbb-frame_1781_crop0.jpg
# 720 1280
# datasets/new/images/train/dfd4dd52-frame_64.jpg
# w, h 10 10
# width, height 1280 720
# 641 89 1281 729
# Saved crop: datasets/new_sliced/images/train/dfd4dd52-frame_64_crop0.jpg
# 720 1280
# datasets/new/images/train/fee84281-frame_840.jpg
# w, h 11 11
# width, height 1280 720
# 326 24 966 664
# Saved crop: datasets/new_sliced/images/train/fee84281-frame_840_crop0.jpg
# 720 1280
# datasets/new/images/train/e35877d3-frame_1.jpg
# w, h 19 18
# width, height 1280 720
# 98 8 738 648
# Saved crop: datasets/new_sliced/images/train/e35877d3-frame_1_crop0.jpg
# 720 1280
# datasets/new/images/train/3bdf25c5-frame_1858.jpg
# w, h 16 15
# width, height 1280 720
# 523 44 1163 684
# Saved crop: datasets/new_sliced/images/train/3bdf25c5-frame_1858_crop0.jpg
# 720 1280
# datasets/new/images/train/7b02d0c4-frame_1141.jpg
# w, h 10 9
# width, height 1280 720
# 360 81 1000 721
# Saved crop: datasets/new_sliced/images/train/7b02d0c4-frame_1141_crop0.jpg
# 1920 1080
# datasets/new/images/train/8310058e-frame_1030.jpg
# w, h 28 25
# width, height 1080 1920
# 295 1185 935 1825
# Saved crop: datasets/new_sliced/images/train/8310058e-frame_1030_crop0.jpg
# 720 1280
# datasets/new/images/train/4e792a53-frame_152.jpg
# w, h 14 13
# width, height 1280 720
# 512 59 1152 699
# Saved crop: datasets/new_sliced/images/train/4e792a53-frame_152_crop0.jpg
# 720 1280
# datasets/new/images/train/80dff5ec-frame_57.jpg
# w, h 10 11
# width, height 1280 720
# 321 20 961 660
# Saved crop: datasets/new_sliced/images/train/80dff5ec-frame_57_crop0.jpg
# 720 1280
# datasets/new/images/train/3bd8a5df-frame_176.jpg
# w, h 13 12
# width, height 1280 720
# 355 13 995 653
# Saved crop: datasets/new_sliced/images/train/3bd8a5df-frame_176_crop0.jpg
# 720 1280
# datasets/new/images/train/46c27b8a-frame_1583.jpg
# w, h 12 12
# width, height 1280 720
# 283 16 923 656
# Saved crop: datasets/new_sliced/images/train/46c27b8a-frame_1583_crop0.jpg
# 720 1280
# datasets/new/images/train/100ce9b5-frame_1492.jpg
# w, h 20 18
# width, height 1280 720
# 129 52 769 692
# Saved crop: datasets/new_sliced/images/train/100ce9b5-frame_1492_crop0.jpg
# 720 1280
# datasets/new/images/train/8b2d1e2e-frame_698.jpg
# w, h 12 13
# width, height 1280 720
# 338 56 978 696
# Saved crop: datasets/new_sliced/images/train/8b2d1e2e-frame_698_crop0.jpg
# 720 1280
# datasets/new/images/train/1b1ecfb9-frame_45.jpg
# w, h 12 9
# width, height 1280 720
# 571 77 1211 717
# Saved crop: datasets/new_sliced/images/train/1b1ecfb9-frame_45_crop0.jpg
# 720 1280
# datasets/new/images/train/bd9ed539-frame_49.jpg
# w, h 10 6
# width, height 1280 720
# 460 15 1100 655
# Saved crop: datasets/new_sliced/images/train/bd9ed539-frame_49_crop0.jpg
# 720 1280
# datasets/new/images/train/4d14450f-frame_8.jpg
# w, h 18 16
# width, height 1280 720
# 152 35 792 675
# Saved crop: datasets/new_sliced/images/train/4d14450f-frame_8_crop0.jpg
# 720 1280
# datasets/new/images/train/db8557e1-frame_2142.jpg
# w, h 12 12
# width, height 1280 720
# 6 15 646 655
# Saved crop: datasets/new_sliced/images/train/db8557e1-frame_2142_crop0.jpg
# 720 1280
# datasets/new/images/train/8d695a56-frame_191.jpg
# w, h 13 13
# width, height 1280 720
# 416 86 1056 726
# Saved crop: datasets/new_sliced/images/train/8d695a56-frame_191_crop0.jpg
# 720 1280
# datasets/new/images/train/307d446a-frame_11252.jpg
# w, h 35 35
# width, height 1280 720
# 535 24 1175 664
# Saved crop: datasets/new_sliced/images/train/307d446a-frame_11252_crop0.jpg
# 720 1280
# datasets/new/images/train/e2086540-frame_109.jpg
# w, h 12 11
# width, height 1280 720
# 364 21 1004 661
# Saved crop: datasets/new_sliced/images/train/e2086540-frame_109_crop0.jpg
# 1920 1080
# datasets/new/images/train/ad47d62e-frame_970.jpg
# w, h 17 18
# width, height 1080 1920
# 128 626 768 1266
# Saved crop: datasets/new_sliced/images/train/ad47d62e-frame_970_crop0.jpg
# 720 1280
# datasets/new/images/train/a92b1a5e-frame_1287.jpg
# w, h 12 12
# width, height 1280 720
# 389 72 1029 712
# Saved crop: datasets/new_sliced/images/train/a92b1a5e-frame_1287_crop0.jpg
# 720 1280
# datasets/new/images/train/c26f2829-frame_2106.jpg
# w, h 38 38
# width, height 1280 720
# 659 48 1299 688
# Saved crop: datasets/new_sliced/images/train/c26f2829-frame_2106_crop0.jpg
# 720 1280
# datasets/new/images/train/8dc7d1be-frame_1740.jpg
# w, h 17 15
# width, height 1280 720
# 209 69 849 709
# Saved crop: datasets/new_sliced/images/train/8dc7d1be-frame_1740_crop0.jpg
# 720 1280
# datasets/new/images/train/4bc8b959-frame_187.jpg
# w, h 13 13
# width, height 1280 720
# 455 70 1095 710
# Saved crop: datasets/new_sliced/images/train/4bc8b959-frame_187_crop0.jpg
# 720 1280
# datasets/new/images/train/10c4b775-frame_70.jpg
# w, h 11 10
# width, height 1280 720
# 134 81 774 721
# Saved crop: datasets/new_sliced/images/train/10c4b775-frame_70_crop0.jpg
# 1920 1080
# datasets/new/images/train/9708e244-frame_980.jpg
# w, h 19 18
# width, height 1080 1920
# 138 538 778 1178
# Saved crop: datasets/new_sliced/images/train/9708e244-frame_980_crop0.jpg
# 720 1280
# datasets/new/images/train/2e2fdd1c-frame_1695.jpg
# w, h 16 15
# width, height 1280 720
# 344 23 984 663
# Saved crop: datasets/new_sliced/images/train/2e2fdd1c-frame_1695_crop0.jpg
# 720 1280
# datasets/new/images/train/2e8c8e12-frame_1671.jpg
# w, h 16 14
# width, height 1280 720
# 278 55 918 695
# Saved crop: datasets/new_sliced/images/train/2e8c8e12-frame_1671_crop0.jpg
# 720 1280
# datasets/new/images/train/d19f5bd2-frame_1396.jpg
# w, h 19 20
# width, height 1280 720
# 245 52 885 692
# Saved crop: datasets/new_sliced/images/train/d19f5bd2-frame_1396_crop0.jpg
# 1920 1080
# datasets/new/images/train/8fc5617d-frame_430.jpg
# w, h 20 19
# width, height 1080 1920
# 87 1291 727 1931
# Saved crop: datasets/new_sliced/images/train/8fc5617d-frame_430_crop0.jpg
# 720 1280
# datasets/new/images/train/fc110db5-frame_2089.jpg
# w, h 16 16
# width, height 1280 720
# 608 71 1248 711
# Saved crop: datasets/new_sliced/images/train/fc110db5-frame_2089_crop0.jpg
# 1920 1080
# datasets/new/images/train/ad20a01d-frame_1020.jpg
# w, h 22 21
# width, height 1080 1920
# 14 605 654 1245
# Saved crop: datasets/new_sliced/images/train/ad20a01d-frame_1020_crop0.jpg
# 720 1280
# datasets/new/images/train/5517727e-frame_1964.jpg
# w, h 12 14
# width, height 1280 720
# 91 35 731 675
# Saved crop: datasets/new_sliced/images/train/5517727e-frame_1964_crop0.jpg
# 720 1280
# datasets/new/images/train/4c40d28c-frame_2160.jpg
# w, h 12 12
# width, height 1280 720
# 465 49 1105 689
# Saved crop: datasets/new_sliced/images/train/4c40d28c-frame_2160_crop0.jpg
# 720 1280
# datasets/new/images/train/946b8fc3-frame_191.jpg
# w, h 17 17
# width, height 1280 720
# 554 8 1194 648
# Saved crop: datasets/new_sliced/images/train/946b8fc3-frame_191_crop0.jpg
# 720 1280
# datasets/new/images/train/40eea220-frame_2031.jpg
# w, h 9 9
# width, height 1280 720
# 139 1 779 641
# Saved crop: datasets/new_sliced/images/train/40eea220-frame_2031_crop0.jpg
# 1920 1080
# datasets/new/images/train/95d3d43a-frame_550.jpg
# w, h 17 15
# width, height 1080 1920
# 41 871 681 1511
# Saved crop: datasets/new_sliced/images/train/95d3d43a-frame_550_crop0.jpg
# 720 1280
# datasets/new/images/train/2ac1bab1-frame_149.jpg
# w, h 12 13
# width, height 1280 720
# 399 21 1039 661
# Saved crop: datasets/new_sliced/images/train/2ac1bab1-frame_149_crop0.jpg
# 720 1280
# datasets/new/images/train/2f6c5e1f-frame_425.jpg
# w, h 13 12
# width, height 1280 720
# 311 34 951 674
# Saved crop: datasets/new_sliced/images/train/2f6c5e1f-frame_425_crop0.jpg
# 720 1280
# datasets/new/images/train/30372455-frame_10.jpg
# w, h 17 16
# width, height 1280 720
# 164 9 804 649
# Saved crop: datasets/new_sliced/images/train/30372455-frame_10_crop0.jpg
# 720 1280
# datasets/new/images/train/8f5482be-frame_1099.jpg
# w, h 10 10
# width, height 1280 720
# 455 35 1095 675
# Saved crop: datasets/new_sliced/images/train/8f5482be-frame_1099_crop0.jpg
# 1920 1080
# datasets/new/images/train/6e4699ad-frame_460.jpg
# w, h 17 17
# width, height 1080 1920
# 393 925 1033 1565
# Saved crop: datasets/new_sliced/images/train/6e4699ad-frame_460_crop0.jpg
# 720 1280
# datasets/new/images/train/72431384-frame_12713.jpg
# w, h 46 41
# width, height 1280 720
# 618 82 1258 722
# Saved crop: datasets/new_sliced/images/train/72431384-frame_12713_crop0.jpg
# 720 1280
# datasets/new/images/train/ea77789f-frame_157.jpg
# w, h 15 14
# width, height 1280 720
# 477 75 1117 715
# Saved crop: datasets/new_sliced/images/train/ea77789f-frame_157_crop0.jpg
# 720 1280
# datasets/new/images/train/334bd2b1-frame_1019.jpg
# w, h 15 14
# width, height 1280 720
# 316 59 956 699
# Saved crop: datasets/new_sliced/images/train/334bd2b1-frame_1019_crop0.jpg
# 720 1280
# datasets/new/images/train/bc178a82-frame_98.jpg
# w, h 11 10
# width, height 1280 720
# 651 23 1291 663
# Saved crop: datasets/new_sliced/images/train/bc178a82-frame_98_crop0.jpg
# 720 1280
# datasets/new/images/train/8fc3ec5b-frame_2079.jpg
# w, h 14 16
# width, height 1280 720
# 228 81 868 721
# Saved crop: datasets/new_sliced/images/train/8fc3ec5b-frame_2079_crop0.jpg
# 720 1280
# datasets/new/images/train/17f6bb23-frame_6035.jpg
# w, h 19 14
# width, height 1280 720
# 150 19 790 659
# Saved crop: datasets/new_sliced/images/train/17f6bb23-frame_6035_crop0.jpg
# 720 1280
# datasets/new/images/train/5ccc2442-frame_14.jpg
# w, h 16 16
# width, height 1280 720
# 69 55 709 695
# Saved crop: datasets/new_sliced/images/train/5ccc2442-frame_14_crop0.jpg
# 720 1280
# datasets/new/images/train/d5e9bd79-frame_1299.jpg
# w, h 17 15
# width, height 1280 720
# 36 34 676 674
# Saved crop: datasets/new_sliced/images/train/d5e9bd79-frame_1299_crop0.jpg
# 720 1280
# datasets/new/images/train/a959deca-frame_386.jpg
# w, h 15 17
# width, height 1280 720
# 420 69 1060 709
# Saved crop: datasets/new_sliced/images/train/a959deca-frame_386_crop0.jpg
# 720 1280
# datasets/new/images/train/911e22ae-frame_375.jpg
# w, h 15 16
# width, height 1280 720
# 501 72 1141 712
# Saved crop: datasets/new_sliced/images/train/911e22ae-frame_375_crop0.jpg
# 720 1280
# datasets/new/images/train/07ad3123-frame_163.jpg
# w, h 12 12
# width, height 1280 720
# 567 26 1207 666
# Saved crop: datasets/new_sliced/images/train/07ad3123-frame_163_crop0.jpg
# 720 1280
# datasets/new/images/train/4bfa7d74-frame_12.jpg
# w, h 17 15
# width, height 1280 720
# 158 53 798 693
# Saved crop: datasets/new_sliced/images/train/4bfa7d74-frame_12_crop0.jpg
# 720 1280
# datasets/new/images/train/04271044-frame_582.jpg
# w, h 15 14
# width, height 1280 720
# 524 4 1164 644
# Saved crop: datasets/new_sliced/images/train/04271044-frame_582_crop0.jpg
# 1920 1080
# datasets/new/images/train/7cfe030b-frame_220.jpg
# w, h 29 31
# width, height 1080 1920
# 197 516 837 1156
# Saved crop: datasets/new_sliced/images/train/7cfe030b-frame_220_crop0.jpg
# 720 1280
# datasets/new/images/train/b365b6fa-frame_6.jpg
# w, h 18 15
# width, height 1280 720
# 14 41 654 681
# Saved crop: datasets/new_sliced/images/train/b365b6fa-frame_6_crop0.jpg
# 720 1280
# datasets/new/images/train/2f133be8-frame_1361.jpg
# w, h 13 11
# width, height 1280 720
# 291 51 931 691
# Saved crop: datasets/new_sliced/images/train/2f133be8-frame_1361_crop0.jpg
# 720 1280
# datasets/new/images/train/2df6ca7b-frame_76.jpg
# w, h 11 10
# width, height 1280 720
# 490 86 1130 726
# Saved crop: datasets/new_sliced/images/train/2df6ca7b-frame_76_crop0.jpg
# 720 1280
# datasets/new/images/train/2f9d4191-frame_2122.jpg
# w, h 24 24
# width, height 1280 720
# 504 7 1144 647
# Saved crop: datasets/new_sliced/images/train/2f9d4191-frame_2122_crop0.jpg
# 1920 1080
# datasets/new/images/train/ec587b18-frame_490.jpg
# w, h 14 13
# width, height 1080 1920
# 187 899 827 1539
# Saved crop: datasets/new_sliced/images/train/ec587b18-frame_490_crop0.jpg
# 720 1280
# datasets/new/images/train/b0d12449-frame_200.jpg
# w, h 12 11
# width, height 1280 720
# 434 43 1074 683
# Saved crop: datasets/new_sliced/images/train/b0d12449-frame_200_crop0.jpg
# 720 1280
# datasets/new/images/train/73be52a2-frame_53.jpg
# w, h 10 10
# width, height 1280 720
# 471 63 1111 703
# Saved crop: datasets/new_sliced/images/train/73be52a2-frame_53_crop0.jpg
# 720 1280
# datasets/new/images/train/1dd5ff72-frame_2116.jpg
# w, h 30 31
# width, height 1280 720
# 621 89 1261 729
# Saved crop: datasets/new_sliced/images/train/1dd5ff72-frame_2116_crop0.jpg
# 1920 1080
# datasets/new/images/train/305dfdbf-frame_410.jpg
# ...
# w, h 30 29
# width, height 1280 720
# 592 1 1232 641
# Saved crop: datasets/new_sliced/images/train/475df0f0-frame_1384_crop0.jpg
# 720 1280
# datasets/new/images/train/ed91eaea-frame_106.jpg
# w, h 13 12
# width, height 1280 720
# 335 92 975 732
# Saved crop: datasets/new_sliced/images/train/ed91eaea-frame_106_crop0.jpg
# 720 1280
# datasets/new/images/train/82d5e099-frame_792.jpg
# w, h 11 13
# width, height 1280 720
# 396 27 1036 667
# Saved crop: datasets/new_sliced/images/train/82d5e099-frame_792_crop0.jpg
# 720 1280
# datasets/new/images/train/46129b1b-frame_1952.jpg
# w, h 12 12
# width, height 1280 720
# 315 55 955 695
# Saved crop: datasets/new_sliced/images/train/46129b1b-frame_1952_crop0.jpg
# 720 1280
# datasets/new/images/train/721878c1-frame_2116.jpg
# w, h 31 31
# width, height 1280 720
# 167 56 807 696
# Saved crop: datasets/new_sliced/images/train/721878c1-frame_2116_crop0.jpg
# 720 1280
# datasets/new/images/train/0e24a74d-frame_1344.jpg
# w, h 12 13
# width, height 1280 720
# 535 7 1175 647
# Saved crop: datasets/new_sliced/images/train/0e24a74d-frame_1344_crop0.jpg
# 720 1280
# datasets/new/images/train/5a44d725-frame_135.jpg
# w, h 12 13
# width, height 1280 720
# 30 88 670 728
# Saved crop: datasets/new_sliced/images/train/5a44d725-frame_135_crop0.jpg
# 720 1280
# datasets/new/images/train/a155d6aa-frame_964.jpg
# w, h 11 11
# width, height 1280 720
# 97 83 737 723
# Saved crop: datasets/new_sliced/images/train/a155d6aa-frame_964_crop0.jpg
# 1920 1080
# datasets/new/images/train/484c6f1d-frame_470.jpg
# w, h 15 14
# width, height 1080 1920
# 79 638 719 1278
# Saved crop: datasets/new_sliced/images/train/484c6f1d-frame_470_crop0.jpg
# 720 1280
# datasets/new/images/train/63a5ba3a-frame_540.jpg
# w, h 15 14
# width, height 1280 720
# 103 78 743 718
# Saved crop: datasets/new_sliced/images/train/63a5ba3a-frame_540_crop0.jpg
# 720 1280
# datasets/new/images/train/33c716f4-frame_933.jpg
# w, h 9 8
# width, height 1280 720
# 182 7 822 647
# Saved crop: datasets/new_sliced/images/train/33c716f4-frame_933_crop0.jpg
# 720 1280
# datasets/new/images/train/525929f9-frame_129.jpg
# w, h 14 15
# width, height 1280 720
# 176 42 816 682
# Saved crop: datasets/new_sliced/images/train/525929f9-frame_129_crop0.jpg
# 720 1280
# datasets/new/images/train/b2aac8c8-frame_182.jpg
# w, h 14 14
# width, height 1280 720
# 496 0 1136 640
# Saved crop: datasets/new_sliced/images/train/b2aac8c8-frame_182_crop0.jpg
# 720 1280
# datasets/new/images/train/a3d03f88-frame_107.jpg
# w, h 12 12
# width, height 1280 720
# 364 33 1004 673
# Saved crop: datasets/new_sliced/images/train/a3d03f88-frame_107_crop0.jpg
# 720 1280
# datasets/new/images/train/dce7fdb8-frame_155.jpg
# w, h 18 20
# width, height 1280 720
# 525 31 1165 671
# Saved crop: datasets/new_sliced/images/train/dce7fdb8-frame_155_crop0.jpg
# 720 1280
# datasets/new/images/train/3c15328e-frame_40.jpg
# w, h 11 8
# width, height 1280 720
# 528 13 1168 653
# Saved crop: datasets/new_sliced/images/train/3c15328e-frame_40_crop0.jpg
# 720 1280
# datasets/new/images/train/fcf017b9-frame_21.jpg
# w, h 10 9
# width, height 1280 720
# 145 11 785 651
# Saved crop: datasets/new_sliced/images/train/fcf017b9-frame_21_crop0.jpg
# 720 1280
# datasets/new/images/train/960a1552-frame_169.jpg
# w, h 13 12
# width, height 1280 720
# 653 12 1293 652
# Saved crop: datasets/new_sliced/images/train/960a1552-frame_169_crop0.jpg
# 720 1280
# datasets/new/images/train/d7b72a12-frame_35.jpg
# w, h 15 14
# width, height 1280 720
# 423 12 1063 652
# Saved crop: datasets/new_sliced/images/train/d7b72a12-frame_35_crop0.jpg
# 720 1280
# datasets/new/images/train/23028ab7-frame_121.jpg
# w, h 14 15
# width, height 1280 720
# 507 47 1147 687
# Saved crop: datasets/new_sliced/images/train/23028ab7-frame_121_crop0.jpg
# 720 1280
# datasets/new/images/train/bf8188ee-frame_1277.jpg
# w, h 13 10
# width, height 1280 720
# 47 19 687 659
# Saved crop: datasets/new_sliced/images/train/bf8188ee-frame_1277_crop0.jpg
# 720 1280
# datasets/new/images/train/89546ec5-frame_1754.jpg
# w, h 15 15
# width, height 1280 720
# 208 1 848 641
# Saved crop: datasets/new_sliced/images/train/89546ec5-frame_1754_crop0.jpg
# 720 1280
# datasets/new/images/train/d2e0e552-frame_1385.jpg
# w, h 29 28
# width, height 1280 720
# 549 59 1189 699
# Saved crop: datasets/new_sliced/images/train/d2e0e552-frame_1385_crop0.jpg
# 720 1280
# datasets/new/images/train/8ab00548-frame_2147.jpg
# w, h 10 9
# width, height 1280 720
# 184 85 824 725
# Saved crop: datasets/new_sliced/images/train/8ab00548-frame_2147_crop0.jpg
# 1920 1080
# datasets/new/images/train/9cb0ca1e-frame_600.jpg
# w, h 18 17
# width, height 1080 1920
# 65 1207 705 1847
# Saved crop: datasets/new_sliced/images/train/9cb0ca1e-frame_600_crop0.jpg
# 720 1280
# datasets/new/images/train/9a315e57-frame_2109.jpg
# w, h 37 39
# width, height 1280 720
# 653 2 1293 642
# Saved crop: datasets/new_sliced/images/train/9a315e57-frame_2109_crop0.jpg
# 720 1280
# datasets/new/images/train/08b39958-frame_2103.jpg
# w, h 39 38
# width, height 1280 720
# 516 0 1156 640
# Saved crop: datasets/new_sliced/images/train/08b39958-frame_2103_crop0.jpg
# 1920 1080
# datasets/new/images/train/192332b2-frame_710.jpg
# w, h 22 23
# width, height 1080 1920
# 180 557 820 1197
# Saved crop: datasets/new_sliced/images/train/192332b2-frame_710_crop0.jpg
# 720 1280
# datasets/new/images/train/47088809-frame_970.jpg
# w, h 12 12
# width, height 1280 720
# 80 33 720 673
# Saved crop: datasets/new_sliced/images/train/47088809-frame_970_crop0.jpg
# 720 1280
# datasets/new/images/train/8a4c2c93-frame_2105.jpg
# w, h 39 39
# width, height 1280 720
# 608 32 1248 672
# Saved crop: datasets/new_sliced/images/train/8a4c2c93-frame_2105_crop0.jpg
# 720 1280
# datasets/new/images/train/8e49d73e-frame_89.jpg
# w, h 12 11
# width, height 1280 720
# 438 13 1078 653
# Saved crop: datasets/new_sliced/images/train/8e49d73e-frame_89_crop0.jpg
# 1920 1080
# datasets/new/images/train/e57450b5-frame_760.jpg
# w, h 20 20
# width, height 1080 1920
# 118 817 758 1457
# Saved crop: datasets/new_sliced/images/train/e57450b5-frame_760_crop0.jpg
# 720 1280
# datasets/new/images/train/52214a37-frame_2139.jpg
# w, h 12 11
# width, height 1280 720
# 196 33 836 673
# Saved crop: datasets/new_sliced/images/train/52214a37-frame_2139_crop0.jpg
# 720 1280
# datasets/new/images/train/c2ecb718-frame_1281.jpg
# w, h 14 10
# width, height 1280 720
# 341 66 981 706
# Saved crop: datasets/new_sliced/images/train/c2ecb718-frame_1281_crop0.jpg
# 720 1280
# datasets/new/images/train/4c279d02-frame_33.jpg
# w, h 13 12
# width, height 1280 720
# 266 39 906 679
# Saved crop: datasets/new_sliced/images/train/4c279d02-frame_33_crop0.jpg
# 720 1280
# datasets/new/images/train/3b7394d9-frame_60.jpg
# w, h 11 10
# width, height 1280 720
# 594 3 1234 643
# Saved crop: datasets/new_sliced/images/train/3b7394d9-frame_60_crop0.jpg
# 720 1280
# datasets/new/images/train/33be3db7-frame_1121.jpg
# w, h 8 10
# width, height 1280 720
# 421 6 1061 646
# Saved crop: datasets/new_sliced/images/train/33be3db7-frame_1121_crop0.jpg
# 720 1280
# datasets/new/images/train/629fd70b-frame_61.jpg
# w, h 11 11
# width, height 1280 720
# 415 15 1055 655
# Saved crop: datasets/new_sliced/images/train/629fd70b-frame_61_crop0.jpg
# 720 1280
# datasets/new/images/train/84482908-frame_31.jpg
# w, h 11 10
# width, height 1280 720
# 30 55 670 695
# Saved crop: datasets/new_sliced/images/train/84482908-frame_31_crop0.jpg
# 720 1280
# datasets/new/images/train/b7948bb2-frame_1376.jpg
# w, h 39 35
# width, height 1280 720
# 460 105 1100 745
# Saved crop: datasets/new_sliced/images/train/b7948bb2-frame_1376_crop0.jpg
# 720 1280
# datasets/new/images/train/2b22ce38-frame_1094.jpg
# w, h 8 8
# width, height 1280 720
# 100 55 740 695
# Saved crop: datasets/new_sliced/images/train/2b22ce38-frame_1094_crop0.jpg
# 720 1280
# datasets/new/images/train/a6aae2d1-frame_207.jpg
# w, h 17 16
# width, height 1280 720
# 523 29 1163 669
# Saved crop: datasets/new_sliced/images/train/a6aae2d1-frame_207_crop0.jpg
# 720 1280
# datasets/new/images/train/e7e7c2e3-frame_172.jpg
# w, h 13 13
# width, height 1280 720
# 524 81 1164 721
# Saved crop: datasets/new_sliced/images/train/e7e7c2e3-frame_172_crop0.jpg
# 720 1280
# datasets/new/images/train/8de02bc1-frame_395.jpg
# w, h 23 23
# width, height 1280 720
# 179 69 819 709
# Saved crop: datasets/new_sliced/images/train/8de02bc1-frame_395_crop0.jpg
# 720 1280
# datasets/new/images/train/6714117c-frame_2059.jpg
# w, h 22 20
# width, height 1280 720
# 499 70 1139 710
# Saved crop: datasets/new_sliced/images/train/6714117c-frame_2059_crop0.jpg
# 720 1280
# datasets/new/images/train/36980658-frame_93.jpg
# w, h 9 9
# width, height 1280 720
# 170 61 810 701
# Saved crop: datasets/new_sliced/images/train/36980658-frame_93_crop0.jpg
# 720 1280
# datasets/new/images/train/1f9ad8ab-frame_1374.jpg
# w, h 40 37
# width, height 1280 720
# 542 113 1182 753
# Saved crop: datasets/new_sliced/images/train/1f9ad8ab-frame_1374_crop0.jpg
# 720 1280
# datasets/new/images/train/cc936532-frame_178.jpg
# w, h 12 13
# width, height 1280 720
# 182 66 822 706
# Saved crop: datasets/new_sliced/images/train/cc936532-frame_178_crop0.jpg
# 720 1280
# datasets/new/images/train/8e5735b2-frame_1395.jpg
# w, h 17 17
# width, height 1280 720
# 510 47 1150 687
# Saved crop: datasets/new_sliced/images/train/8e5735b2-frame_1395_crop0.jpg
# 720 1280
# datasets/new/images/train/88023352-frame_2033.jpg
# w, h 23 21
# width, height 1280 720
# 460 87 1100 727
# Saved crop: datasets/new_sliced/images/train/88023352-frame_2033_crop0.jpg
# 720 1280
# datasets/new/images/train/866f1b9a-frame_2114.jpg
# w, h 34 32
# width, height 1280 720
# 465 52 1105 692
# Saved crop: datasets/new_sliced/images/train/866f1b9a-frame_2114_crop0.jpg
# 720 1280
# datasets/new/images/train/7923c6bd-frame_585.jpg
# w, h 18 17
# width, height 1280 720
# 243 12 883 652
# Saved crop: datasets/new_sliced/images/train/7923c6bd-frame_585_crop0.jpg
# 720 1280
# datasets/new/images/train/211cdb24-frame_41.jpg
# w, h 11 9
# width, height 1280 720
# 450 54 1090 694
# Saved crop: datasets/new_sliced/images/train/211cdb24-frame_41_crop0.jpg
# 720 1280
# datasets/new/images/train/ce6d2cf7-frame_2117.jpg
# w, h 30 30
# width, height 1280 720
# 595 24 1235 664
# Saved crop: datasets/new_sliced/images/train/ce6d2cf7-frame_2117_crop0.jpg
# 720 1280
# datasets/new/images/train/5179442c-frame_147.jpg
# w, h 13 11
# width, height 1280 720
# 458 52 1098 692
# Saved crop: datasets/new_sliced/images/train/5179442c-frame_147_crop0.jpg
# 720 1280
# datasets/new/images/train/747b1a4d-frame_882.jpg
# w, h 11 10
# width, height 1280 720
# 466 81 1106 721
# Saved crop: datasets/new_sliced/images/train/747b1a4d-frame_882_crop0.jpg
# 720 1280
# datasets/new/images/train/cdc4b3b0-frame_605.jpg
# w, h 26 25
# width, height 1280 720
# 46 49 686 689
# Saved crop: datasets/new_sliced/images/train/cdc4b3b0-frame_605_crop0.jpg
# 720 1280
# datasets/new/images/train/3648e0ba-frame_3076.jpg
# w, h 17 16
# width, height 1280 720
# 217 83 857 723
# Saved crop: datasets/new_sliced/images/train/3648e0ba-frame_3076_crop0.jpg
# 720 1280
# datasets/new/images/train/1658c157-frame_111.jpg
# w, h 13 13
# width, height 1280 720
# 316 47 956 687
# Saved crop: datasets/new_sliced/images/train/1658c157-frame_111_crop0.jpg
# 720 1280
# datasets/new/images/train/d1888f9c-frame_1297.jpg
# w, h 11 11
# width, height 1280 720
# 382 58 1022 698
# Saved crop: datasets/new_sliced/images/train/d1888f9c-frame_1297_crop0.jpg
# 720 1280
# datasets/new/images/train/d1c05b40-frame_11952.jpg
# w, h 27 27
# width, height 1280 720
# 176 97 816 737
# Saved crop: datasets/new_sliced/images/train/d1c05b40-frame_11952_crop0.jpg
# 720 1280
# datasets/new/images/train/0f8c18dd-frame_1705.jpg
# w, h 14 15
# width, height 1280 720
# 604 92 1244 732
# Saved crop: datasets/new_sliced/images/train/0f8c18dd-frame_1705_crop0.jpg
# 720 1280
# datasets/new/images/train/917d8eea-frame_832.jpg
# w, h 9 11
# width, height 1280 720
# 187 87 827 727
# Saved crop: datasets/new_sliced/images/train/917d8eea-frame_832_crop0.jpg
# 720 1280
# datasets/new/images/train/071a2a9f-frame_652.jpg
# w, h 20 19
# width, height 1280 720
# 505 57 1145 697
# Saved crop: datasets/new_sliced/images/train/071a2a9f-frame_652_crop0.jpg
# 720 1280
# datasets/new/images/train/c55fa0f9-frame_1418.jpg
# w, h 11 10
# width, height 1280 720
# 286 70 926 710
# Saved crop: datasets/new_sliced/images/train/c55fa0f9-frame_1418_crop0.jpg
# 720 1280
# datasets/new/images/train/7bdf09df-frame_153.jpg
# w, h 12 12
# width, height 1280 720
# 191 63 831 703
# Saved crop: datasets/new_sliced/images/train/7bdf09df-frame_153_crop0.jpg
# 720 1280
# datasets/new/images/train/46ac7adb-frame_1391.jpg
# w, h 22 24
# width, height 1280 720
# 535 28 1175 668
# Saved crop: datasets/new_sliced/images/train/46ac7adb-frame_1391_crop0.jpg
# 720 1280
# datasets/new/images/train/5a6b99bb-frame_1103.jpg
# w, h 9 9
# width, height 1280 720
# 28 84 668 724
# Saved crop: datasets/new_sliced/images/train/5a6b99bb-frame_1103_crop0.jpg
# 720 1280
# datasets/new/images/train/e66ff197-frame_7.jpg
# w, h 19 17
# width, height 1280 720
# 87 29 727 669
# Saved crop: datasets/new_sliced/images/train/e66ff197-frame_7_crop0.jpg
# 720 1280
# datasets/new/images/train/5f37b49c-frame_2174.jpg
# w, h 14 12
# width, height 1280 720
# 277 40 917 680
# Saved crop: datasets/new_sliced/images/train/5f37b49c-frame_2174_crop0.jpg
# 720 1280
# datasets/new/images/train/3d30f44b-frame_2109.jpg
# w, h 37 39
# width, height 1280 720
# 625 59 1265 699
# Saved crop: datasets/new_sliced/images/train/3d30f44b-frame_2109_crop0.jpg
# 1920 1080
# datasets/new/images/train/8f689418-frame_680.jpg
# w, h 23 20
# width, height 1080 1920
# 186 444 826 1084
# Saved crop: datasets/new_sliced/images/train/8f689418-frame_680_crop0.jpg
# 1920 1080
# datasets/new/images/train/5c23f19d-frame_880.jpg
# w, h 18 18
# width, height 1080 1920
# 449 1179 1089 1819
# Saved crop: datasets/new_sliced/images/train/5c23f19d-frame_880_crop0.jpg
# 720 1280
# datasets/new/images/train/7d9452a3-frame_1372.jpg
# w, h 42 39
# width, height 1280 720
# 656 56 1296 696
# Saved crop: datasets/new_sliced/images/train/7d9452a3-frame_1372_crop0.jpg
# 720 1280
# datasets/new/images/train/15c4a179-frame_7406.jpg
# w, h 13 12
# width, height 1280 720
# 6 3 646 643
# Saved crop: datasets/new_sliced/images/train/15c4a179-frame_7406_crop0.jpg
# 720 1280
# datasets/new/images/train/a7b36a6f-frame_1887.jpg
# w, h 15 14
# width, height 1280 720
# 400 76 1040 716
# Saved crop: datasets/new_sliced/images/train/a7b36a6f-frame_1887_crop0.jpg
# 1920 1080
# datasets/new/images/train/4ef0ef77-frame_420.jpg
# w, h 19 20
# width, height 1080 1920
# 457 428 1097 1068
# Saved crop: datasets/new_sliced/images/train/4ef0ef77-frame_420_crop0.jpg
# 720 1280
# datasets/new/images/train/21913c95-frame_1436.jpg
# w, h 13 13
# width, height 1280 720
# 615 45 1255 685
# Saved crop: datasets/new_sliced/images/train/21913c95-frame_1436_crop0.jpg
# 720 1280
# datasets/new/images/train/3b9b14e4-frame_2035.jpg
# w, h 10 8
# width, height 1280 720
# 49 5 689 645
# Saved crop: datasets/new_sliced/images/train/3b9b14e4-frame_2035_crop0.jpg
# 720 1280
# datasets/new/images/train/9f07a7a6-frame_13.jpg
# w, h 16 15
# width, height 1280 720
# 78 40 718 680
# Saved crop: datasets/new_sliced/images/train/9f07a7a6-frame_13_crop0.jpg
# 1920 1080
# datasets/new/images/train/ffc60189-frame_560.jpg
# w, h 16 16
# width, height 1080 1920
# 204 1022 844 1662
# Saved crop: datasets/new_sliced/images/train/ffc60189-frame_560_crop0.jpg
# 720 1280
# datasets/new/images/train/1c6e41c0-frame_1526.jpg
# w, h 20 19
# width, height 1280 720
# 150 19 790 659
# Saved crop: datasets/new_sliced/images/train/1c6e41c0-frame_1526_crop0.jpg
# 720 1280
# datasets/new/images/train/2744ea92-frame_1821.jpg
# w, h 15 14
# width, height 1280 720
# 330 47 970 687
# Saved crop: datasets/new_sliced/images/train/2744ea92-frame_1821_crop0.jpg
# 1920 1080
# datasets/new/images/train/613590d1-frame_650.jpg
# w, h 17 16
# width, height 1080 1920
# 89 1245 729 1885
# Saved crop: datasets/new_sliced/images/train/613590d1-frame_650_crop0.jpg
# 720 1280
# datasets/new/images/train/b25f36b9-frame_1472.jpg
# w, h 16 15
# width, height 1280 720
# 219 89 859 729
# Saved crop: datasets/new_sliced/images/train/b25f36b9-frame_1472_crop0.jpg
# 720 1280
# datasets/new/images/train/5e2e28f6-frame_75.jpg
# w, h 11 10
# width, height 1280 720
# 274 70 914 710
# Saved crop: datasets/new_sliced/images/train/5e2e28f6-frame_75_crop0.jpg
# 720 1280
# datasets/new/images/train/17826453-frame_1909.jpg
# w, h 15 14
# width, height 1280 720
# 208 25 848 665
# Saved crop: datasets/new_sliced/images/train/17826453-frame_1909_crop0.jpg
# 720 1280
# datasets/new/images/train/11b03861-frame_3.jpg
# w, h 19 16
# width, height 1280 720
# 26 53 666 693
# Saved crop: datasets/new_sliced/images/train/11b03861-frame_3_crop0.jpg
